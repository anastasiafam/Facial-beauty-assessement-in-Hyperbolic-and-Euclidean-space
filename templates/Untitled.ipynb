# %%
# %%HTML
# <html lang="en">
#
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <meta http-equiv="X-UA-Compatible" content="ie=edge">
#     <title>Оценка привлекательности лица</title>
#
#
#     <link href="https://cdn.bootcss.com/bootstrap/4.0.0/css/bootstrap.min.css" rel="stylesheet">
#     <script src="https://cdn.bootcss.com/popper.js/1.12.9/umd/popper.min.js"></script>
#     <script src="https://cdn.bootcss.com/jquery/3.3.1/jquery.min.js"></script>
#     <script src="https://cdn.bootcss.com/bootstrap/4.0.0/js/bootstrap.min.js"></script>
#     <!-- Google Fonts - Roboto -->
#     <link rel="stylesheet" href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap">
#
#     <link href="{{ url_for('static', filename='css/main.css') }}" rel="stylesheet">
#
#
#
# </head>
#
# <body>
#         <div class="container">
#         <div class="header">
#             <h2>Оценка привлекательности лица</h2>
#         </div>
#         </div>
# </body>
#
# <main>
#
#     <div class="container">
#         <div class="row">
#             <div class="custom-container">
#                 <div class="col-sm">
#                 <h2>Инструкция</h2>
#                 <p>Для получения оценки сперва выберите модель и датасет, на котором она была натренирована.</p>
#
#                 <div class="form-check custom-radio">
#                     <input class="form-check-input" type="radio" name="exampleRadio" id="model_evk" value="option1" checked>
#                     <label class="form-check-label" for="model_evk">
#                         Модель, реализованная в Евклидовом пространстве
#                     </label>
#                 </div>
#
#                 <div class="form-check custom-radio">
#                     <input class="form-check-input" type="radio" name="exampleRadio" id="model_giper" value="option2">
#                     <label class="form-check-label" for="model_giper">
#                         Модель, реализованная в гиперболическом пространстве
#                     </label>
#                 </div>
#
#                 <p>Загрузите изображение</p>
#
#                 <div>
#                     <form id="upload-file" method="post" enctype="multipart/form-data">
#                         <label for="imageUpload" class="upload-label">
#                         Загрузить
#                         </label>
#                         <input type="file" name="file" id="imageUpload" accept=".jpg, .jpeg, image/jpeg, image/jpg">
#                     </form>
#                 </div>
#                 </div>
#
#             <div class="col-sm">
#                 <div class="image-section" style="display:none;">
#                     <div class="img-preview">
#                     <div id="imagePreview">
#                     </div>
#                     </div>
#
#                     <div class="custom-button">
#                         <button type="button" class="btn btn-primary" id="btn-predict">Получить оценку</button>
#                     </div>
#
#
#                 </div>
#
#                 <div class="loader" style="display:none;"></div>
#
#                 <h3 id="result">
#                 <span> </span>
#                 </h3>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <script src="{{ url_for('static', filename='js/main.js') }}" type="text/javascript"></script>
# </main>
#
#
#
# </html>
